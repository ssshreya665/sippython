# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as web
import datetime

# %%
start = datetime.datetime(2017, 1, 1)
end = datetime.datetime(2019, 7, 24)

# %%
bharti_airtel = web. DataReader("BHARTIARTL.NS", "yahoo", start, end)

# %%
bharti_airtel
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-01-02  286.471985  278.299988  278.299988  285.553009   1612972.0
# 2017-01-03  288.261993  275.454010  286.425995  279.539001   3225790.0
# 2017-01-04  289.410004  274.673004  277.657013  288.216003   5669757.0
# 2017-01-05  296.571991  284.681000  287.528015  294.826996   4189622.0
# 2017-01-06  302.998993  292.256012  293.036987  293.588013   2607971.0
# 2017-01-09  295.102997  290.328003  294.368011  291.934998   2586554.0
# 2017-01-10  294.734985  291.108002  292.898987  293.908997   1038675.0
# 2017-01-11  298.087006  292.714996  294.826996  296.342010   2561671.0
# 2017-01-12  298.729004  293.816986  296.984985  295.470001   1649319.0
# 2017-01-13  298.407990  290.144012  296.020996  294.001007   2565985.0
# 2017-01-16  296.938995  291.338013  293.816986  292.532013   1837201.0
# 2017-01-17  293.632996  291.153992  292.807007  292.440002   2013199.0
# ...

# %%
bharti_airtel.head()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2017-01-02  286.471985  278.299988  278.299988  285.553009  1612972.0
# 2017-01-03  288.261993  275.454010  286.425995  279.539001  3225790.0
# 2017-01-04  289.410004  274.673004  277.657013  288.216003  5669757.0
# 2017-01-05  296.571991  284.681000  287.528015  294.826996  4189622.0
# 2017-01-06  302.998993  292.256012  293.036987  293.588013  2607971.0
#
#              Adj Close
# Date
# 2017-01-02  278.237366
# 2017-01-03  272.377441
# 2017-01-04  280.832153
# 2017-01-05  287.273773
# 2017-01-06  286.066559

# %%
bharti_airtel.tail()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2019-07-19  346.000000  336.100006  343.500000  339.950012  2470956.0
# 2019-07-22  343.500000  335.600006  339.000000  342.549988  3062655.0
# 2019-07-23  348.500000  337.399994  342.950012  343.600006  3614547.0
# 2019-07-24  344.750000  335.750000  344.000000  338.899994  4751576.0
# 2019-07-25  343.450012  334.549988    0.000000  340.000000  3224897.0
#
#              Adj Close
# Date
# 2019-07-19  339.950012
# 2019-07-22  342.549988
# 2019-07-23  343.600006
# 2019-07-24  338.899994
# 2019-07-25  340.000000

# %%
bharti_airtel.describe
# Out:
# <bound method NDFrame.describe of                   High         Low        Open       Close      Volume  \
# Date
# 2017-01-02  286.471985  278.299988  278.299988  285.553009   1612972.0
# 2017-01-03  288.261993  275.454010  286.425995  279.539001   3225790.0
# 2017-01-04  289.410004  274.673004  277.657013  288.216003   5669757.0
# 2017-01-05  296.571991  284.681000  287.528015  294.826996   4189622.0
# 2017-01-06  302.998993  292.256012  293.036987  293.588013   2607971.0
# 2017-01-09  295.102997  290.328003  294.368011  291.934998   2586554.0
# 2017-01-10  294.734985  291.108002  292.898987  293.908997   1038675.0
# 2017-01-11  298.087006  292.714996  294.826996  296.342010   2561671.0
# 2017-01-12  298.729004  293.816986  296.984985  295.470001   1649319.0
# 2017-01-13  298.407990  290.144012  296.020996  294.001007   2565985.0
# 2017-01-16  296.938995  291.338013  293.816986  292.532013   1837201.0
# 2017-01-17  293.632996  291.153992  292.807007  292.440002   2013199.0
# ...

# %%
bharti_airtel.Close.plot()

# %%
bharti_airtel.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
bharti_airtel[["Open","High","Low","Close"]]
# Out:
#                   Open        High         Low       Close
# Date
# 2017-01-02  278.299988  286.471985  278.299988  285.553009
# 2017-01-03  286.425995  288.261993  275.454010  279.539001
# 2017-01-04  277.657013  289.410004  274.673004  288.216003
# 2017-01-05  287.528015  296.571991  284.681000  294.826996
# 2017-01-06  293.036987  302.998993  292.256012  293.588013
# 2017-01-09  294.368011  295.102997  290.328003  291.934998
# 2017-01-10  292.898987  294.734985  291.108002  293.908997
# 2017-01-11  294.826996  298.087006  292.714996  296.342010
# 2017-01-12  296.984985  298.729004  293.816986  295.470001
# 2017-01-13  296.020996  298.407990  290.144012  294.001007
# 2017-01-16  293.816986  296.938995  291.338013  292.532013
# 2017-01-17  292.807007  293.632996  291.153992  292.440002
# 2017-01-18  291.980988  292.714996  285.782990  288.216003
# 2017-01-19  288.308014  296.204010  285.553009  291.153992
# 2017-01-20  288.354004  300.703003  288.354004  294.321991
# ...

# %%
bharti_airtel[["Open","High","Low","Close"]].plot()

# %%
bharti_airtel["Close"].plot(grid=True)
bharti_airtel["Open"].plot(grid=True)
plt.legend()
plt.show()

# %%
bharti_airtel["High"].plot(grid=True)
bharti_airtel["Low"].plot(grid=True)
plt.legend()
plt.show()

# %%
#for monthly level
monthly_df = bharti_airtel.resample("M").mean()
print(monthly_df)
# Out:
#                   High         Low        Open       Close        Volume  \
# Date
# 2017-01-31  298.639711  288.563667  291.530426  294.112193  4.672155e+06
# 2017-02-28  337.075422  325.965366  329.860424  330.515267  6.660237e+06
# 2017-03-31  327.969094  319.672087  324.822277  323.782999  4.450587e+06
# 2017-04-30  321.492554  313.522164  317.332669  318.041614  3.590338e+06
# 2017-05-31  339.767731  329.841001  333.198499  334.529953  6.119871e+06
# 2017-06-30  343.033619  336.326525  339.155433  339.223192  3.577175e+06
# 2017-07-31  376.188665  366.324614  370.882810  371.851429  4.461953e+06
# 2017-08-31  390.155906  382.104143  386.765096  386.467807  2.820688e+06
# 2017-09-30  370.867619  361.230956  367.166475  366.036143  4.106562e+06
# 2017-10-31  412.776349  399.157399  404.395601  407.526501  1.073114e+07
# 2017-11-30  471.426179  457.784865  465.124132  463.684316  1.135580e+07
# 2017-12-31  483.806598  468.247852  475.747148  476.422052  7.188722e+06
# ...

# %%
daily_close = bharti_airtel[["Adj Close"]]
daily_pct_change = daily_close.pct_change()
daily_pct_change.fillna(0, inplace=True)

# %%
print(daily_pct_change)
# Out:
#             Adj Close
# Date
# 2017-01-02   0.000000
# 2017-01-03  -0.021061
# 2017-01-04   0.031040
# 2017-01-05   0.022938
# 2017-01-06  -0.004202
# 2017-01-09  -0.005630
# 2017-01-10   0.006762
# 2017-01-11   0.008278
# 2017-01-12  -0.002942
# 2017-01-13  -0.004972
# 2017-01-16  -0.004997
# 2017-01-17  -0.000315
# 2017-01-18  -0.014444
# 2017-01-19   0.010194
# 2017-01-20   0.010881
# 2017-01-23  -0.002806
# 2017-01-24  -0.009857
# 2017-01-25  -0.016270
# 2017-01-27   0.039825
# 2017-01-30   0.067645
# 2017-01-31   0.007379
# 2017-02-01  -0.008905
# 2017-02-02   0.023761
# 2017-02-03   0.001418
# 2017-02-06   0.004097
# 2017-02-07  -0.005911
# 2017-02-08  -0.002692
# 2017-02-09   0.008662
# 2017-02-10   0.006475
# 2017-02-13   0.001398
# ...               ...
# 2019-06-14  -0.028729
# 2019-06-17  -0.026323
# 2019-06-18   0.003343
# 2019-06-19  -0.011734
# 2019-06-20   0.021841
# 2019-06-21  -0.013628
# 2019-06-24   0.003781
# 2019-06-25   0.010142
# 2019-06-26  -0.008749
# ...

# %%
#resample to business months take last observation as value
monthly = bharti_airtel.resample("BM").apply(lambda x: x[-1])
monthly.pct_change()
# Out:
#                 High       Low      Open     Close    Volume  Adj Close
# Date
# 2017-01-31       NaN       NaN       NaN       NaN       NaN        NaN
# 2017-02-28  0.056939  0.038917  0.022778  0.048679  0.149682   0.048679
# 2017-03-31 -0.055749 -0.031986 -0.019610 -0.041354 -0.570931  -0.041354
# 2017-04-28  0.015896  0.015942  0.015145  0.015569 -0.484102   0.015569
# 2017-05-31  0.053086  0.050071  0.052632  0.045148  4.723279   0.045148
# 2017-06-30  0.018575  0.012360  0.022592  0.021935 -0.787679   0.021935
# 2017-07-31  0.097810  0.100376  0.085110  0.103373 -0.185880   0.106407
# 2017-08-31  0.024558  0.034512  0.040481  0.020885  1.678809   0.020885
# 2017-09-29 -0.092519 -0.106095 -0.115447 -0.089431 -0.325475  -0.089431
# 2017-10-31  0.284676  0.283661  0.282890  0.276670  1.377798   0.276670
# 2017-11-30 -0.007947  0.008425  0.004797 -0.001507  0.172472  -0.001507
# 2017-12-29  0.078194  0.063569  0.080126  0.066874 -0.495814   0.066874
# ...

# %%
bharti_airtel["diff"] = bharti_airtel.Open - bharti_airtel.Close
bharti_airtel["diff"]
# Out:
# Date
# 2017-01-02     -7.253021
# 2017-01-03      6.886993
# 2017-01-04    -10.558990
# 2017-01-05     -7.298981
# 2017-01-06     -0.551025
# 2017-01-09      2.433014
# 2017-01-10     -1.010010
# 2017-01-11     -1.515015
# 2017-01-12      1.514984
# 2017-01-13      2.019989
# 2017-01-16      1.284973
# 2017-01-17      0.367004
# 2017-01-18      3.764984
# 2017-01-19     -2.845978
# 2017-01-20     -5.967987
# 2017-01-23      1.238983
# 2017-01-24      1.377991
# 2017-01-25     -5.830994
# 2017-01-27    -12.348999
# 2017-01-30    -20.705017
# 2017-01-31      0.779999
# 2017-02-01      0.826996
# 2017-02-02     -7.619995
# 2017-02-03     -0.459991
# 2017-02-06     -1.148010
# 2017-02-07      0.963989
# 2017-02-08      2.571014
# 2017-02-09     -2.938019
# 2017-02-10     -0.505005
# 2017-02-13     -4.223999
#                  ...
# 2019-06-14      9.250000
# 2019-06-17     11.600006
# 2019-06-18      0.250000
# 2019-06-19      5.399994
# 2019-06-20     -9.299988
# ...

# %%
#resample to quaters, take the mean as value per quarter
quarter = bharti_airtel.resample("4M").mean()

#calculate the quaterly percentage change 
quarter.pct_change()
# Out:
#                 High       Low      Open     Close    Volume  Adj Close  \
# Date
# 2017-01-31       NaN       NaN       NaN       NaN       NaN        NaN
# 2017-05-31  0.111274  0.117755  0.120345  0.111838  0.119637   0.111838
# 2017-09-30  0.115078  0.120768  0.120563  0.118926 -0.284743   0.121005
# 2018-01-31  0.238428  0.228411  0.233438  0.232525  1.581864   0.233809
# 2018-05-31 -0.178451 -0.178895 -0.177560 -0.179277 -0.207471  -0.173599
# 2018-09-30 -0.081191 -0.081297 -0.081940 -0.080264 -0.366249  -0.077203
# 2019-01-31 -0.159780 -0.166355 -0.163062 -0.163096  0.551760  -0.154283
# 2019-05-31  0.088974  0.093834  0.088938  0.092092  0.146148   0.094676
# 2019-09-30  0.123506  0.135484  0.103057  0.129056 -0.403136   0.129056
#
#                  diff
# Date
# 2017-01-31        NaN
# 2017-05-31  -0.848745
# 2017-09-30  -1.250472
# 2018-01-31   3.649145
# 2018-05-31   1.525248
# 2018-09-30  -0.622142
# 2019-01-31  -0.135969
# 2019-05-31  -2.308435
# 2019-09-30  16.593424

# %%
daily_pct_change.hist(bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B6E7F99128>]],
#       dtype=object)

# %%
#factor change - current price / starting price
bharti_airtel["change_factor"] = bharti_airtel["Open"]/bharti_airtel["Close"]

# %%
bharti_airtel["change_factor"]
# Out:
# Date
# 2017-01-02    0.974600
# 2017-01-03    1.024637
# 2017-01-04    0.963364
# 2017-01-05    0.975243
# 2017-01-06    0.998123
# 2017-01-09    1.008334
# 2017-01-10    0.996564
# 2017-01-11    0.994888
# 2017-01-12    1.005127
# 2017-01-13    1.006871
# 2017-01-16    1.004393
# 2017-01-17    1.001255
# 2017-01-18    1.013063
# 2017-01-19    0.990225
# 2017-01-20    0.979723
# 2017-01-23    1.004221
# 2017-01-24    1.004742
# 2017-01-25    0.979603
# 2017-01-27    0.958457
# 2017-01-30    0.934760
# 2017-01-31    1.002440
# 2017-02-01    1.002610
# 2017-02-02    0.976510
# 2017-02-03    0.998584
# 2017-02-06    0.996480
# 2017-02-07    1.002973
# 2017-02-08    1.007950
# 2017-02-09    0.990993
# 2017-02-10    0.998462
# 2017-02-13    0.987151
#                 ...
# 2019-06-14    1.026182
# 2019-06-17    1.033721
# 2019-06-18    1.000724
# 2019-06-19    1.015831
# 2019-06-20    0.973318
# 2019-06-21    1.010762
# 2019-06-24    1.000145
# 2019-06-25    0.990964
# ...

# %%
from matplotlib.dates import DateFormatter, WeekdayLocator,\
    DayLocator, MONDAY
from mpl_finance import candlestick_ohlc
def pandas_candlestick_ohlc(bharti_airtel, stick = "month", otherseries = None):
    ""''

# %%
bharti_airtel["24m"] = np.round(bharti_airtel["Close"].rolling(window = 20, center = False).mean(), 2)
pandas_candlestick_ohlc(bharti_airtel.loc['2019-07-24':'2019-08-24',:], otherseries = "24m")

# %%
(bharti_airtel["24m"]).plot(grid=True)
plt.show()

# %%
def get(tickers, startdate, enddate):
  def data(ticker):
    return (web.get_data_yahoo(ticker, start=startdate, end=enddate))
  datas = map (data, tickers)
  return(pd.concat(datas, keys=tickers, names=['Ticker', 'Date']))

tickers = ['AAPL', 'MSFT', 'IBM', 'GOOG','INTC']
all_data = get(tickers, datetime.datetime(2017, 1, 1), datetime.datetime(2019, 7, 24))
all_data.head()
# Out:
#                          High         Low        Open       Close      Volume  \
# Ticker Date
# AAPL   2017-01-03  116.330002  114.760002  115.800003  116.150002  28781900.0
#        2017-01-04  116.510002  115.750000  115.849998  116.019997  21118100.0
#        2017-01-05  116.860001  115.809998  115.919998  116.610001  22193600.0
#        2017-01-06  118.160004  116.470001  116.779999  117.910004  31751900.0
#        2017-01-09  119.430000  117.940002  117.949997  118.989998  33561900.0
#
#                     Adj Close
# Ticker Date
# AAPL   2017-01-03  111.709831
#        2017-01-04  111.584778
#        2017-01-05  112.152229
#        2017-01-06  113.402542
#        2017-01-09  114.441246

# %%
# Isolate the `Adj Close` values and transform the DataFrame
daily_close_px = all_data[['Adj Close']].reset_index().pivot('Date', 'Ticker', 'Adj Close')

# Calculate the daily percentage change for `daily_close_px`
daily_pct_change = daily_close_px.pct_change()

# Plot the distributions
daily_pct_change.hist(bins=50, sharex=True, figsize=(12,8))

# Show the resulting plot
plt.show()

# %%
# Isolate the adjusted closing prices 
adj_close_px = bharti_airtel['Adj Close']

# Calculate the moving average
moving_avg = adj_close_px.rolling(window=40).mean()

# Inspect the result
print(moving_avg[-365:])
# Out:
# Date
# 2018-01-30    456.402335
# 2018-01-31    455.475158
# 2018-02-01    454.372809
# 2018-02-02    453.069449
# 2018-02-05    451.468376
# 2018-02-06    449.609216
# 2018-02-07    447.379683
# 2018-02-08    445.338480
# 2018-02-09    443.278168
# 2018-02-12    441.194633
# 2018-02-14    439.398708
# 2018-02-15    437.284506
# 2018-02-16    434.729210
# 2018-02-19    432.225777
# 2018-02-20    429.914712
# 2018-02-21    427.538869
# 2018-02-22    424.759866
# 2018-02-23    422.380465
# 2018-02-26    420.020860
# 2018-02-27    417.865405
# 2018-02-28    415.705145
# 2018-03-01    413.781378
# 2018-03-05    411.678299
# 2018-03-06    409.297049
# 2018-03-07    406.292864
# 2018-03-08    403.776174
# 2018-03-09    401.425573
# 2018-03-12    399.589394
# 2018-03-13    397.673237
# 2018-03-14    395.790130
#                  ...
# 2019-06-14    336.483502
# 2019-06-17    337.102227
# 2019-06-18    337.725602
# 2019-06-19    338.289052
# 2019-06-20    338.982501
# ...

# %%
bharti_airtel['Adj Close'].tail(5)
# Out:
# Date
# 2019-07-19    339.950012
# 2019-07-22    342.549988
# 2019-07-23    343.600006
# 2019-07-24    338.899994
# 2019-07-25    340.000000
# Name: Adj Close, dtype: float64

# %%
bharti_airtel["50d"] = np.round(bharti_airtel["Close"].rolling(window = 50, center = False).mean(), 2)
bharti_airtel["365d"] = np.round(bharti_airtel["Close"].rolling(window = 365, center = True).mean(), 2)
 
pandas_candlestick_ohlc(bharti_airtel.loc['2019-01-01':'2020-07-24',:], otherseries = ["50d", "365d"])
bharti_airtel["365d"].plot(grid=True)
plt.show()

# %%
stock_change = bharti_airtel.apply(lambda x: np.log(x) - np.log(x.shift(1))) # shift moves dates back by 1.
stock_change.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
#                 High       Low      Open     Close    Volume  Adj Close  diff  \
# Date
# 2017-01-02       NaN       NaN       NaN       NaN       NaN        NaN   NaN
# 2017-01-03  0.006229 -0.010279  0.028781 -0.021286  0.693099  -0.021286   NaN
# 2017-01-04  0.003975 -0.002839 -0.031094  0.030568  0.563968   0.030568   NaN
# 2017-01-05  0.024446  0.035788  0.034934  0.022679 -0.302536   0.022679   NaN
# 2017-01-06  0.021439  0.026261  0.018979 -0.004211 -0.474038  -0.004211   NaN
#
#             change_factor  24m  50d  365d
# Date
# 2017-01-02            NaN  NaN  NaN   NaN
# 2017-01-03       0.050066  NaN  NaN   NaN
# ...

# %%
stock_change.plot(grid = True).axhline(y = 0, color = "black", lw = 2)

# %%
stock_change_apr = stock_change * 252 * 100    # There are 252 trading days in a year; the 100 converts to percentages
stock_change_apr.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2019-07-19 -375.911461 -186.750518 -327.987276 -188.321460 -9781.060952
# 2019-07-22 -182.741918  -37.516755 -332.312508  191.999126  5409.862077
# 2019-07-23  364.168187  134.798813  291.931722   77.127399  4175.245613
# 2019-07-24 -272.631581 -123.538379   77.035337 -347.083311  6892.447362
# 2019-07-25  -95.204100  -90.229272        -inf   81.662037 -9766.898587
#
#              Adj Close          diff  change_factor        24m        50d  \
# Date
# 2019-07-19 -188.321460 -11032.658969    -139.665816 -13.595514  35.557865
# 2019-07-22  191.999126           NaN    -524.311634  -9.306422  26.816609
# 2019-07-23   77.127399           NaN     214.804324 -17.906630  36.193382
# 2019-07-24 -347.083311           NaN     424.118649 -23.656252   2.893226
# 2019-07-25   81.662037           NaN           -inf -31.576254  13.015409
#
#             365d
# Date
# 2019-07-19   NaN
# 2019-07-22   NaN
# ...

# %%
bharti_airtel["20d"] = np.round(bharti_airtel["Adj Close"].rolling(window = 20, center = False).mean(), 2)
pandas_candlestick_ohlc(bharti_airtel.loc['2019-01-04':'2019-12-31',:], otherseries = "20d")

# %%
bharti_airtel["20d"].plot(grid = True)

# %%
bharti_airtel['20d-50d'] = bharti_airtel['20d'] - bharti_airtel['50d']
bharti_airtel.tail()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2019-07-19  346.000000  336.100006  343.500000  339.950012  2470956.0
# 2019-07-22  343.500000  335.600006  339.000000  342.549988  3062655.0
# 2019-07-23  348.500000  337.399994  342.950012  343.600006  3614547.0
# 2019-07-24  344.750000  335.750000  344.000000  338.899994  4751576.0
# 2019-07-25  343.450012  334.549988    0.000000  340.000000  3224897.0
#
#              Adj Close        diff  change_factor     24m     50d  365d  \
# Date
# 2019-07-19  339.950012    3.549988       1.010443  352.08  347.51   NaN
# 2019-07-22  342.549988   -3.549988       0.989637  351.95  347.88   NaN
# 2019-07-23  343.600006   -0.649994       0.998108  351.70  348.38   NaN
# 2019-07-24  338.899994    5.100006       1.015049  351.37  348.42   NaN
# 2019-07-25  340.000000 -340.000000       0.000000  350.93  348.60   NaN
#
#                20d  20d-50d
# Date
# 2019-07-19  352.08     4.57
# 2019-07-22  351.95     4.07
# ...

# %%
# np.where() is a vectorized if-else function, where a condition is checked for each component of a vector, and the first argument passed is used when the condition holds, and the other passed if it does not
bharti_airtel["Regime"] = np.where(bharti_airtel['20d-50d'] > 0, 1, 0)
# We have 1's for bullish regimes and 0's for everything else. Below I replace bearish regimes's values with -1, and to maintain the rest of the vector, the second argument is apple["Regime"]
bharti_airtel["Regime"] = np.where(bharti_airtel['20d-50d'] < 0, -1, bharti_airtel["Regime"])
bharti_airtel.loc['2016-01-04':'2019-12-31',"Regime"].plot(ylim = (-2,2)).axhline(y = 0, color = "black", lw = 2)

# %%
bharti_airtel["Regime"].value_counts()
# Out:
# -1    320
#  1    264
#  0     49
# Name: Regime, dtype: int64

# %%
# To ensure that all trades close out, I temporarily change the regime of the last row to 0
regime_orig = bharti_airtel.loc[:, "Regime"].iloc[-1]
bharti_airtel.loc[:, "Regime"].iloc[-1] = 0
bharti_airtel["Signal"] = np.sign(bharti_airtel["Regime"] - bharti_airtel["Regime"].shift(1))
# Restore original regime data
bharti_airtel.loc[:, "Regime"].iloc[-1] = regime_orig
bharti_airtel.tail()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in sign
#   after removing the cwd from sys.path.
#                   High         Low        Open       Close     Volume  \
# Date
# 2019-07-19  346.000000  336.100006  343.500000  339.950012  2470956.0
# 2019-07-22  343.500000  335.600006  339.000000  342.549988  3062655.0
# 2019-07-23  348.500000  337.399994  342.950012  343.600006  3614547.0
# 2019-07-24  344.750000  335.750000  344.000000  338.899994  4751576.0
# 2019-07-25  343.450012  334.549988    0.000000  340.000000  3224897.0
#
# ...

# %%
bharti_airtel["Signal"].value_counts()
# Out:
#  0.0    614
# -1.0      9
#  1.0      9
# Name: Signal, dtype: int64

# %%
bharti_airtel.loc[bharti_airtel["Signal"] == 1, "Close"]
# Out:
# Date
# 2017-03-15    333.481995
# 2017-05-25    340.368988
# 2017-07-18    374.891998
# 2017-10-26    469.464996
# 2018-01-03    475.799988
# 2018-01-11    472.631989
# 2018-08-23    339.634003
# 2018-12-03    293.588013
# 2019-03-15    310.069000
# Name: Close, dtype: float64

# %%
bharti_airtel.loc[bharti_airtel["Signal"] == -1, "Close"]
# Out:
# Date
# 2017-03-24    312.640015
# 2017-06-19    337.431000
# 2017-09-06    369.566986
# 2017-12-20    485.625000
# 2018-01-10    464.966003
# 2018-01-16    456.563995
# 2018-09-28    310.848999
# 2019-02-07    285.691010
# 2019-07-25    340.000000
# Name: Close, dtype: float64

# %%
# Create a DataFrame with trades, including the price at the trade and the regime under which the trade is made.
bharti_airtel_signals = pd.concat([
        pd.DataFrame({"Price": bharti_airtel.loc[bharti_airtel["Signal"] == 1, "Adj Close"],
                     "Regime": bharti_airtel.loc[bharti_airtel["Signal"] == 1, "Regime"],
                     "Signal": "Buy"}),
        pd.DataFrame({"Price": bharti_airtel.loc[bharti_airtel["Signal"] == -1, "Adj Close"],
                     "Regime": bharti_airtel.loc[bharti_airtel["Signal"] == -1, "Regime"],
                     "Signal": "Sell"}),
    ])
bharti_airtel_signals.sort_index(inplace = True)
bharti_airtel_signals
# Out:
#                  Price  Regime Signal
# Date
# 2017-03-15  324.938477       1    Buy
# 2017-03-24  304.630432      -1   Sell
# 2017-05-25  331.649017       1    Buy
# 2017-06-19  328.786285      -1   Sell
# 2017-07-18  366.292175       1    Buy
# 2017-09-06  361.089325      -1   Sell
# 2017-10-26  458.695740       1    Buy
# 2017-12-20  474.485046      -1   Sell
# 2018-01-03  464.885406       1    Buy
# 2018-01-10  454.299927      -1   Sell
# 2018-01-11  461.790100       1    Buy
# 2018-01-16  446.090668      -1   Sell
# 2018-08-23  336.572449       1    Buy
# 2018-09-28  308.046906      -1   Sell
# 2018-12-03  293.588013       1    Buy
# 2019-02-07  285.691010      -1   Sell
# 2019-03-15  310.069000       1    Buy
# 2019-07-25  340.000000       1   Sell
